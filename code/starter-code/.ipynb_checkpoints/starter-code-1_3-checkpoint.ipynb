# %% [markdown]
# # Multi-table Datasets - ENRON Archive

# %% [markdown]
# ## 1. Data import
#
# Connect to the file 'assets/datasets/enron.db' using one of these methods:
#
# - sqlite3 python package
# - pandas.read_sql
# - SQLite Manager Firefox extension
#
# Take a look at the database and query the master table. How many Tables are there in the db?
#
# > Answer:
# There are 3 tables:
# - MessageBase
# - RecipientBase
# - EmployeeBase

# %%
import numpy as np

# %%
import pandas as pd
import sqlite3
sqlite_db = '../../assets/datasets/enron.db'
conn = sqlite3.connect(sqlite_db)
c = conn.cursor()

# %% [markdown]
# Query the `sqlite_master` table to retrieve the schema of the `EmployeeBase` table.
#
# 1. What fields are there?
# 1. What's the type of each of them?

# %%
c.execute("SELECT * FROM sqlite_master WHERE type='table' AND name='EmployeeBase'")
print(c.fetchone())
# Out:
# (u'table', u'EmployeeBase', u'EmployeeBase', 2, u'CREATE TABLE EmployeeBase (\n                  [eid] INTEGER,\n  [name] TEXT,\n  [department] TEXT,\n  [longdepartment] TEXT,\n  [title] TEXT,\n  [gender] TEXT,\n  [seniority] TEXT\n                  \n                  )')

# %%
print "Fields: eid, name, department, longdepartment, title, gender, seniority"
print "Types: integer, text, text, text, text, text, text"
# Out:
# Fields: eid, name, department, longdepartment, title, gender, seniority
# Types: integer, text, text, text, text, text, text

# %% [markdown]
# 1. Print the first 5 rows of EmployeeBase table
# 1. Print the first 5 rows of MessageBase table
# 1. Print the first 5 rows of RecipientBase table
#
# **Hint**  use `SELECT` and `LIMIT`.

# %%
c.execute("SELECT * FROM 'EmployeeBase' LIMIT 5")
x = c.fetchall()
for i in x:
    print i
# Out:
# (1, u'John Arnold', u'Forestry', u'ENA Gas Financial', u'VP Trading', u'Male', u'Senior')
# (2, u'Harry Arora', u'Forestry', u'ENA East Power', u'VP Trading', u'Male', u'Senior')
# (3, u'Robert Badeer', u'Forestry', u'ENA West Power', u'Mgr Trading', u'Male', u'Junior')
# (4, u'Susan Bailey', u'Legal', u'ENA Legal', u'Specialist Legal', u'Female', u'Junior')
# (5, u'Eric Bass', u'Forestry', u'ENA Gas Texas', u'Trader', u'Male', u'Junior')

# %%
c.execute("SELECT * FROM 'MessageBase' LIMIT 5")
x = c.fetchall()
for i in x:
    print i
# Out:
# (1, u'taylor-m/sent/11', 910930020, u'Cd$ CME letter', 138)
# (2, u'taylor-m/sent/17', 911459940, u'Indemnification', 138)
# (3, u'taylor-m/sent/18', 911463840, u'Re: Indemnification', 138)
# (4, u'taylor-m/sent/23', 911874180, u'Re: Coral Energy, L.P.', 138)
# (5, u'taylor-m/sent/27', 912396120, u'Bankruptcy Code revisions', 138)

# %%
c.execute("SELECT * FROM 'RecipientBase' LIMIT 5")
x = c.fetchall()
for i in x:
    print i
# Out:
# (1, 1, 59)
# (2, 1, 15)
# (3, 1, 15)
# (4, 1, 109)
# (4, 2, 49)

# %% [markdown]
# Import each of the 3 tables to a Pandas Dataframes

# %%
employee_table = pd.read_sql("SELECT * FROM EmployeeBase", conn)
message_table = pd.read_sql("SELECT * FROM MessageBase", conn)
recipient_table = pd.read_sql("SELECT * FROM RecipientBase", conn)

# %% [markdown]
# ## 2. Data Exploration
#
# Use the 3 dataframes to answer the following questions:
#
# 1. How many employees are there in the company?
# - How many messages are there in the database?
# - Convert the timestamp column in the messages. When was the oldest message sent? And the newest?
# - Some messages are sent to more than one recipient. Group the messages by message_id and count the number of recepients. Then look at the distribution of recepient numbers.
#     - How many messages have only one recepient?
#     - How many messages have >= 5 recepients?
#     - What's the highest number of recepients?
#     - Who sent the message with the highest number of recepients?
# - Plot the distribution of recepient numbers using Bokeh.

# %%
#question 1
#<img src={{i}} class='giphy'>
len(employee_table)
# Out:
# 156

# %%
#question 2

len(message_table)
# Out:
# 21635

# %%
#question 3


message_table.unix_time = pd.to_datetime(message_table.unix_time, unit='s')

# %%
employee_table.head()
# Out:
#    eid           name department     longdepartment             title  gender  \
# 0    1    John Arnold   Forestry  ENA Gas Financial        VP Trading    Male
# 1    2    Harry Arora   Forestry     ENA East Power        VP Trading    Male
# 2    3  Robert Badeer   Forestry     ENA West Power       Mgr Trading    Male
# 3    4   Susan Bailey      Legal          ENA Legal  Specialist Legal  Female
# 4    5      Eric Bass   Forestry      ENA Gas Texas            Trader    Male
#
#   seniority
# 0    Senior
# 1    Senior
# 2    Junior
# 3    Junior
# 4    Junior

# %%
message_table.head()
# Out:
#    mid          filename           unix_time                    subject  \
# 0    1  taylor-m/sent/11 1998-11-13 04:07:00             Cd$ CME letter
# 1    2  taylor-m/sent/17 1998-11-19 07:19:00            Indemnification
# 2    3  taylor-m/sent/18 1998-11-19 08:24:00        Re: Indemnification
# 3    4  taylor-m/sent/23 1998-11-24 02:23:00     Re: Coral Energy, L.P.
# 4    5  taylor-m/sent/27 1998-11-30 03:22:00  Bankruptcy Code revisions
#
#    from_eid
# 0       138
# 1       138
# 2       138
# 3       138
# 4       138

# %%
recipient_table.head()
# Out:
#    mid  rno  to_eid
# 0    1    1      59
# 1    2    1      15
# 2    3    1      15
# 3    4    1     109
# 4    4    2      49

# %%
# question 4

mid_rno = recipient_table.groupby(['mid'])['rno'].count()
one_message = []
five_plus_messages = []
highest_messages = []
highest = 0
for i in mid_rno:
    if i == 1:
        one_message.append(i)
    elif i >= 5:
        five_plus_messages.append(i)
    if highest < i:
        highest = i

# %%
print "Number of 1 recipient messages: ", len(one_message)
print "Number of 5+ recipient messages: ", len(five_plus_messages)
print "Highest number of recipients for 1 message: ", highest
# Out:
# Number of 1 recipient messages:  14985
# Number of 5+ recipient messages:  1380
# Highest number of recipients for 1 message:  57

# %%
import numpy as np
import scipy.special

import bokeh.plotting as bk
from bokeh.layouts import gridplot
from bokeh.plotting import figure, show, output_file
from bokeh.charts import Histogram, output_notebook

bk.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="a9f3c0de-3c47-42ba-9251-c50a59fd57c8">Loading BokehJS ...</span>
#     </div>

# %%
p = Histogram(mid_rno, values="rno", bins=1000)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="886f7b8c-6c2c-49f8-a1f7-58b34afaa412"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#886f7b8c-6c2c-49f8-a1f7-58b34afaa412").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("886f7b8c-6c2c-49f8-a1f7-58b34afaa412");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '886f7b8c-6c2c-49f8-a1f7-58b34afaa412' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"bb4db81d-5075-4f7e-8691-73c45688f292":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"f2f319a9-0472-4db1-8e5f-ffade2fbe93c","type":"Rect"},{"attributes":{"data_source":{"id":"08f61e14-7a20-4145-b40b-be566aeee164","type":"ColumnDataSource"},"glyph":{"id":"d2a02104-c674-499a-83b8-11706f54b5b6","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"76d4fbc1-fdd4-4f75-9df1-5e2966233c0b","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"f6b91dbc-f98c-408a-a49c-1e2a9298d5ff","type":"ColumnDataSource"},"glyph":{"id":"244f68b9-eaac-4b69-ac99-76aa9ae45a51","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"db12a8fc-6b27-4c17-89b0-c5db327e319b","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"d8c265eb-35aa-4c55-933d-af7f2238fc6a","type":"ColumnDataSource"},"glyph":{"id":"c6519e19-f4bd-4ecb-8861-3282f21fd0d7","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"b11a7e55-fbaa-4293-9a9f-083b668b0117","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"522a56b9-137c-4299-8748-60614e625e65","type":"ColumnDataSource"},"glyph":{"id":"373bdc99-e4b6-4b4f-bdda-8e584953bd8f","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"207237ff-dabd-4d99-aa0b-2e4e54646fac","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"8a9612a7-48f8-4bd7-8ec1-1558fbaa1973","type":"ColumnDataSource"},"glyph":{"id":"637a1e49-6f38-4201-99bf-9d0bb74c5088","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"cce9ee90-eb3b-4843-b9a7-5f25900804e3","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"581c6c7e-dc75-4b0a-aece-38a57b72f086","type":"ColumnDataSource"},"glyph":{"id":"560757eb-4da5-41c2-b2dd-6c76dafeef6c","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"053b577f-89cf-4359-849b-a3eba1ce3aa0","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"932f14e8-67c5-4a1e-8211-669969156e73","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"a7ddc2e9-c6c0-444b-91d4-849b05c0cca8","type":"Rect"},{"attributes":{"data_source":{"id":"f046becf-9df8-4a04-bf4e-714a434b2beb","type":"ColumnDataSource"},"glyph":{"id":"236d66c1-c7d3-49d2-96aa-e64d6555cfe2","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"7ef681f5-4f21-4a67-9e2b-3dbc555f52b9","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(23.2, 23.2]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"label":["(23.2, 23.2]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.055999999999997385],"x":["23.2"],"y":[0.0]}},"id":"e65bd6c6-c3c5-4f6f-83af-6c91b9c0b7c9","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"e0589ff0-de72-4278-9818-a4b1a3e91ec8","type":"ColumnDataSource"},"glyph":{"id":"a08c297e-20fe-4837-ac95-dd785a36027c","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"a664904c-2e45-4895-8820-46d7c4a94176","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"lin ...

# %% [markdown]
# Rescale to investigate the tail of the curve

# %% [markdown]
# ## 3. Data Merging
#
# Use the pandas merge function to combine the information in the 3 dataframes to answer the following questions:
#
# 1. Are there more Men or Women employees?
# - How is gender distributed across departments?
# - Who is sending more emails? Men or Women?
# - What's the average number of emails sent by each gender?
# - Are there more Juniors or Seniors?
# - Who is sending more emails? Juniors or Seniors?
# - Which department is sending more emails? How does that relate with the number of employees in the department?
# - Who are the top 3 senders of emails? (people who sent out the most emails)

# %%
message_table.columns = ['mid','filename','datetime','subject','eid']

# %%
#question 1
#Are there more Men or Women employees?
print employee_table.groupby(['gender'])['eid'].count()
print "There are more men than women"
# Out:
# gender
# Female     43
# Male      113
# Name: eid, dtype: int64
# There are more men than women

# %%
#question 2
#How is gender distributed across departments?
#department, gender

pd.pivot_table(employee_table[['department','gender']], columns = ['gender'], index = ['department'], aggfunc = len)
# Out:
# gender      Female  Male
# department
# Forestry        10    50
# Legal           13    12
# Other           20    51

# %%
#question 3
merge3 = employee_table.merge(message_table, how='inner')

print "Number of messages sent by gender:\n", merge3.groupby(['gender'])['eid'].count()
# Out:
# Number of messages sent by gender:
# gender
# Female     8794
# Male      12841
# Name: eid, dtype: int64

# %%
# question 4
# Average number sent by gender

print "male:", len(merge3[(merge3['gender'] == 'Male')])/float(len(employee_table[(employee_table['gender'] == 'Male')]))
print "female:", len(merge3[(merge3['gender'] == 'Female')])/float(len(employee_table[(employee_table['gender'] == 'Female')]))
# Out:
# male: 113.637168142
# female: 204.511627907

# %%
#question 5
employee_table.groupby(['seniority'])['eid'].count()
# Out:
# seniority
# Junior    82
# Senior    74
# Name: eid, dtype: int64

# %%
#question 6
#Who is sending more emails? Juniors or Seniors?
print merge3.groupby(merge3['seniority'])['eid'].count()
# Out:
# seniority
# Junior     9196
# Senior    12439
# Name: eid, dtype: int64

# %%
#question 7
#Which department is sending more emails? How does that relate with the number of employees in the department?
print merge3.department.value_counts()
print employee_table.department.value_counts()
# Out:
# Legal       10396
# Other        6852
# Forestry     4387
# Name: department, dtype: int64
# Other       71
# Forestry    60
# Legal       25
# Name: department, dtype: int64

# %%
#question 8
#Who are the top 3 senders of emails? (people who sent out the most emails)
merge3.name.value_counts()[:3]
# Out:
# Jeff Dasovich      1597
# Tana Jones         1379
# Sara Shackleton    1142
# Name: name, dtype: int64

# %% [markdown]
# Answer the following questions regarding received messages:
#
# - Who is receiving more emails? Men or Women?
# - Who is receiving more emails? Juniors or Seniors?
# - Which department is receiving more emails? How does that relate with the number of employees in the department?
# - Who are the top 5 receivers of emails? (people who received the most emails)

# %%
merge4 = merge3.merge(recipient_table, how="inner")
merge4.head()
# Out:
#    eid         name department     longdepartment       title gender  \
# 0    1  John Arnold   Forestry  ENA Gas Financial  VP Trading   Male
# 1    1  John Arnold   Forestry  ENA Gas Financial  VP Trading   Male
# 2    1  John Arnold   Forestry  ENA Gas Financial  VP Trading   Male
# 3    1  John Arnold   Forestry  ENA Gas Financial  VP Trading   Male
# 4    1  John Arnold   Forestry  ENA Gas Financial  VP Trading   Male
#
#   seniority   mid           filename            datetime  \
# 0    Senior  1611  arnold-j/sent/379 2000-03-29 08:08:00
# 1    Senior  1615  arnold-j/sent/377 2000-03-29 11:22:00
# 2    Senior  1615  arnold-j/sent/377 2000-03-29 11:22:00
# 3    Senior  1615  arnold-j/sent/377 2000-03-29 11:22:00
# 4    Senior  1722  arnold-j/sent/365 2000-04-11 09:58:00
#
#                             subject  rno  to_eid
# 0         Re: Insurance Call Spread    1      42
# 1  New curve generation methodology    1      76
# 2  New curve generation methodology    2      67
# 3  New curve generation methodology    3     121
# 4  Option Analysis on NG Price Book    1      76

# %%
#Who is receiving more emails? Men or Women?
merge4.groupby(merge4['gender'])['eid'].count()
# Out:
# gender
# Female    15590
# Male      22798
# Name: eid, dtype: int64

# %%
#Who is receiving more emails? Juniors or Seniors?
merge4.groupby(merge4['seniority'])['eid'].count()
# Out:
# seniority
# Junior    15898
# Senior    22490
# Name: eid, dtype: int64

# %%
#Which department is receiving more emails? How does that relate with the number of employees in the department?
print merge4.department.value_counts()
print employee_table.department.value_counts()
# Out:
# Legal       19292
# Other       11984
# Forestry     7112
# Name: department, dtype: int64
# Other       71
# Forestry    60
# Legal       25
# Name: department, dtype: int64

# %%
#Who are the top 5 receivers of emails? (people who received the most emails)
merge4.name.value_counts()[:5]
# Out:
# Jeff Dasovich       3844
# Tana Jones          2858
# James D. Steffes    1666
# Sara Shackleton     1515
# Mike Grigsby        1204
# Name: name, dtype: int64

# %% [markdown]
# Which employees sent the most 'mass' emails?

# %%
p = pd.pivot_table(merge4,index=["mid","name"], values=["rno"],
                       aggfunc=len).sort_values(by= 'rno', ascending = False)

# %%
p2 = p.groupby(level=1).first().sort_values(by = 'rno', ascending = False)
p2[:10]
# Out:
#                   rno
# name
# John J. Lavorato   57
# Kenneth Lay        52
# Sally Beck         49
# Monique Sanchez    24
# Louise Kitchen     21
# Susan Scott        21
# Kam Keiser         20
# Mary Hain          17
# Susan M. Scott     16
# Mark E. Haedicke   16

# %% [markdown]
# Keep exploring the dataset, which other questions would you ask?
#
# Work in pairs. Give each other a challenge and try to solve it.
